# %% [markdown]
# <a href="https://colab.research.google.com/github/rklepov/hse-cs-ml-2018-2019/blob/master/10-CV/01-intro/001-sobel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Оператор Собеля

# %%
import cv2
import numpy as np

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
img = cv2.imread('lena.png')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(img[..., ::-1])

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# ## Оператор собеля для вычисления X и Y составляющих градиента

# %%
sobel_x = np.array([[-1, 0, 1],
                    [-2, 0, 2],
                    [-1, 0, 1]])
    
sobel_y = np.array([[-1, -2, -1],
                    [ 0,  0,  0],
                    [ 1,  2,  1]])

# %% [markdown]
# ## Вычисляем градиенты по осям

# %%
grad_x = cv2.filter2D(img_gray, cv2.CV_32F, sobel_x)
grad_y = cv2.filter2D(img_gray, cv2.CV_32F, sobel_y)

# %%
plt.figure(2, figsize=(12, 8))
plt.subplot(121)
plt.imshow(np.abs(grad_x)/np.max(np.abs(grad_x)), cmap='gray')
plt.title('Grad X')
plt.subplot(122)
plt.imshow(np.abs(grad_y)/np.max(np.abs(grad_y)), cmap='gray')
plt.title('Grad Y');

# %% [markdown]
# ## Вычисляем суммарный градиент

# %%
grad = np.sqrt(grad_x ** 2 + grad_y ** 2)
theta = np.arctan2(grad_y, grad_x)

# %%
plt.figure(2, figsize=(12, 4))
plt.subplot(131)
plt.imshow(img_gray, cmap='gray')
plt.subplot(132)
plt.imshow(grad, cmap='gray')
plt.subplot(133)
plt.imshow(theta, cmap='gray')
