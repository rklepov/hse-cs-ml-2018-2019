# %% [markdown]
# <a href="https://colab.research.google.com/github/rklepov/hse-cs-ml-2018-2019/blob/master/10-CV/01-intro/001_colorspace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Цветовые пространства

# %% [markdown]
# ## Загрузка изображения из файла

# %%
import cv2
import numpy as np

# %%
img = cv2.imread('./lena.png', cv2.IMREAD_COLOR)

# %%
print('type: ', type(img))
print('shape: ', img.shape)
# Out:
# type:  <class 'numpy.ndarray'>
# shape:  (512, 512, 3)

# %% [markdown]
# ## Визуализация в matplotlib

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.imshow(img)

# %%
# изменяем порядок каналов для визуализации (b, g, r) -> (r, g, b)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## Переходим в пространство цветов HSV

# %%
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
plt.figure(1, figsize = (16, 4))
plt.subplot(141)
plt.imshow(img[...,::-1])
plt.subplot(142)
plt.imshow(img_hsv[...,0], cmap='gray')
plt.title('Hue')
plt.subplot(143)
plt.imshow(img_hsv[...,1], cmap='gray')
plt.title('Saturation')
plt.subplot(144)
plt.imshow(img_hsv[...,2], cmap='gray')
plt.title('Value');

# %%
plt.imshow(img_hsv)

# %%
plt.imshow(np.mean(img, axis=2), cmap='gray')
