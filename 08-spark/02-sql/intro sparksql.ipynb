# %%
import findspark

findspark.init()

import pyspark

# %%
spark = pyspark.sql.SparkSession.builder.getOrCreate()

# %%
alexa = spark.read.csv("/data/top-1m.csv")

# %%
alexa.show()
# Out:
# +---+---------------+
# |_c0|            _c1|
# +---+---------------+
# |  1|     google.com|
# |  2|    youtube.com|
# |  3|   facebook.com|
# |  4|      baidu.com|
# |  5|  wikipedia.org|
# |  6|         qq.com|
# |  7|     taobao.com|
# |  8|      yahoo.com|
# |  9|      tmall.com|
# | 10|     amazon.com|
# | 11|    twitter.com|
# | 12|       sohu.com|
# | 13|         jd.com|
# | 14|       live.com|
# | 15|    sina.com.cn|
# | 16|  instagram.com|
# | 17|      weibo.com|
# | 18|         360.cn|
# | 19|login.tmall.com|
# | 20|     reddit.com|
# +---+---------------+
# only showing top 20 rows

# %%
alexa.orderBy("_c0").show()
# Out:
# +-------+--------------------+
# |    _c0|                 _c1|
# +-------+--------------------+
# |      1|          google.com|
# |     10|          amazon.com|
# |    100|           zhihu.com|
# |   1000|        turnitin.com|
# |  10000|             kit.edu|
# | 100000|     educateiowa.gov|
# |1000000|  onlythefitness.com|
# | 100001|     wagnardsoft.com|
# | 100002|         myhermes.at|
# | 100003|         pvcloud.com|
# | 100004|descargas-vagos.c...|
# | 100005|       blogvporn.com|
# | 100006|          duedil.com|
# | 100007|      doctorpiter.ru|
# | 100008|      sachbaitap.com|
# | 100009|         iwmbuzz.com|
# |  10001|       37signals.com|
# | 100010|        torrentz2.cc|
# | 100011|       technoxyz.com|
# | 100012|      warkscol.ac.uk|
# +-------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql import types

schema = types.StructType().add("rank", "integer").add("site", "string")

real_alexa = spark.read.csv("/data/top-1m.csv", schema=schema)

# %%
real_alexa.show()
# Out:
# +----+---------------+
# |rank|           site|
# +----+---------------+
# |   1|     google.com|
# |   2|    youtube.com|
# |   3|   facebook.com|
# |   4|      baidu.com|
# |   5|  wikipedia.org|
# |   6|         qq.com|
# |   7|     taobao.com|
# |   8|      yahoo.com|
# |   9|      tmall.com|
# |  10|     amazon.com|
# |  11|    twitter.com|
# |  12|       sohu.com|
# |  13|         jd.com|
# |  14|       live.com|
# |  15|    sina.com.cn|
# |  16|  instagram.com|
# |  17|      weibo.com|
# |  18|         360.cn|
# |  19|login.tmall.com|
# |  20|     reddit.com|
# +----+---------------+
# only showing top 20 rows

# %%
real_alexa.orderBy("rank").show()
# Out:
# +----+---------------+
# |rank|           site|
# +----+---------------+
# |   1|     google.com|
# |   2|    youtube.com|
# |   3|   facebook.com|
# |   4|      baidu.com|
# |   5|  wikipedia.org|
# |   6|         qq.com|
# |   7|     taobao.com|
# |   8|      yahoo.com|
# |   9|      tmall.com|
# |  10|     amazon.com|
# |  11|    twitter.com|
# |  12|       sohu.com|
# |  13|         jd.com|
# |  14|       live.com|
# |  15|    sina.com.cn|
# |  16|  instagram.com|
# |  17|      weibo.com|
# |  18|         360.cn|
# |  19|login.tmall.com|
# |  20|     reddit.com|
# +----+---------------+
# only showing top 20 rows

# %%
real_alexa.printSchema()
# Out:
# root
#  |-- rank: integer (nullable = true)
#  |-- site: string (nullable = true)

# %%
from pyspark.sql import functions

(
    real_alexa
    .select(
        functions.explode(
            functions.split("site", "\.")
        ).alias("token")
    )
    .groupBy("token")
    .count()
    .withColumnRenamed("count", "shmount")
    .orderBy(functions.desc("shmount"))
    .show()
)
# Out:
# +--------+-------+
# |   token|shmount|
# +--------+-------+
# |     com| 529951|
# |     org|  54801|
# |     net|  42212|
# |      ru|  41774|
# |      co|  35863|
# |      de|  30184|
# |      br|  21409|
# |blogspot|  16691|
# |      uk|  16631|
# |      pl|  15019|
# |      in|  13978|
# |      ir|  12242|
# |      it|  11209|
# |      au|  10855|
# |      jp|  10575|
# |      fr|   9801|
# |     gov|   9751|
# |     edu|   8904|
# |    info|   8335|
# |      cz|   7750|
# +--------+-------+
# only showing top 20 rows

# %%
from pyspark.sql import functions

reverse_idx = (
    real_alexa
    .select(
        functions.explode(
            functions.split("site", "\.")
        ).alias("token"),
        functions.col("site"),
        functions.col("rank")
    )
    .groupBy("token")
    .agg(
        {
            "site": "collect_set",
            "rank": "max",
        }
    )
)


reverse_idx.cache()
# Out:
# DataFrame[token: string, collect_set(site): array<string>, max(rank): int]

# %%
reverse_idx.where("token = 'google'").show()
# Out:
# +------+--------------------+---------+
# | token|   collect_set(site)|max(rank)|
# +------+--------------------+---------+
# |google|[safety.google, d...|   953902|
# +------+--------------------+---------+

# %%
reverse_idx.where("token = 'ya'").show()
# Out:
# +-----+--------------------+---------+
# |token|   collect_set(site)|max(rank)|
# +-----+--------------------+---------+
# |   ya|[ya.no, ya.com, y...|   596444|
# +-----+--------------------+---------+

# %%
zgrab = spark.read.json("/data/zgrab.json")

# %%
zgrab.show()
# Out:
# +---------------+--------------------+--------------------+---------------+--------------------+
# |_corrupt_record|                data|               error|             ip|           timestamp|
# +---------------+--------------------+--------------------+---------------+--------------------+
# |           null|               [[,]]|Get http://172.65...| 172.65.100.108|2018-05-13T02:30:...|
# |           null|[[, [<html style=...|                null| 192.230.66.113|2018-05-13T02:30:...|
# |           null|[[, [,,, [,,,,,,,...|                null|  159.65.233.69|2018-05-13T02:30:...|
# |           null|               [[,]]|Get http://168.25...| 168.255.128.19|2018-05-13T02:30:...|
# |           null|[[, [<!doctype ht...|                null| 185.162.171.15|2018-05-13T02:30:...|
# |           null|[[, [<html style=...|                null| 31.201.254.208|2018-05-13T02:30:...|
# |           null|[[, [<!DOCTYPE ht...|                null|  151.40.76.245|2018-05-13T02:30:...|
# |           null|               [[,]]|Get http://112.72...|  112.72.33.128|2018-05-13T02:30:...|
# |           null|[[, [<HTML><HEAD>...|                null| 218.145.166.91|2018-05-13T02:30:...|
# |           null|               [[,]]|Get http://67.222...|   67.222.68.11|2018-05-13T02:30:...|
# |           null|[[, [<html style=...|                null|   45.60.107.95|2018-05-13T02:30:...|
# |           null|[[, [<html><head>...|                null| 118.169.10.116|2018-05-13T02:30:...|
# |           null|[[[[,, -1, [,,,,,...|                null|   45.121.57.70|2018-05-13T02:30:...|
# |           null|               [[,]]|Get http://45.195...|  45.195.160.26|2018-05-13T02:30:...|
# |           null|               [[,]]|Get http://115.13...|115.131.234.198|2018-05-13T02:30:...|
# |           null|               [[,]]|Get http://115.12...|115.128.144.139|2018-05-13T02:30:...|
# |           null|[[, [<u></u><head...|                null| 68.171.217.103|2018-05-13T02:30:...|
# |           null|[[[[<html>
# <head...|Get http://www.du...|  123.60.36.156|2018-05-13T02:30:...|
# |           null|               [[,]]|Get http://119.32...|    119.32.58.2|2018-05-13T02:30:...|
# |           null|               [[,]]|Get http://168.25...|  168.255.58.46|2018-05-13T02:30:...|
# +---------------+--------------------+--------------------+---------------+--------------------+
# only showing top 20 rows

# %%
zgrab.printSchema()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)
#  |-- data: struct (nullable = true)
#  |    |-- http: struct (nullable = true)
#  |    |    |-- redirect_response_chain: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- body: string (nullable = true)
#  |    |    |    |    |-- body_sha256: string (nullable = true)
#  |    |    |    |    |-- content_length: long (nullable = true)
#  |    |    |    |    |-- headers: struct (nullable = true)
#  |    |    |    |    |    |-- accept_ranges: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- access_control_allow_origin: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- cache_control: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- connection: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- content_encoding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- content_language: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- content_length: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- content_security_policy: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- content_type: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- expires: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- last_modified: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- location: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- p3p: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- pragma: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- server: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- set_cookie: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- status: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- strict_transport_security: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- unknown: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- key: string (nullable = true)
#  |    |    |    |    |    |    |    |-- value: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- upgrade: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- vary: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- via: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- x_content_security_policy: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- x_content_type_options: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- x_frame_options: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- x_powered_by: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- x_ua_compatible: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- x_webkit_csp: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- x_xss_protection: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- protocol: struct (nullable = true)
#  |    |    |    |    |    |-- major: long (nullable = true)
#  |    |    |    |    |    |-- minor: long (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- request: struct (nullable = true)
#  |    |    |    |    |    |-- headers: struct (nullable = true)
#  |    |    |    |    |    |    |-- referer: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |-- unknown: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- key: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- host: string (nullable = true)
#  |    |    |    |    |    |-- method: string (nullable = true)
#  |    |    |    |    |    |-- tls_handshake: struct (nullable = true)
#  |    |    |    |    |    |    |-- client_finished: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- verify_data: string (nullable = true)
#  |    |    |    |    |    |    |-- client_hello: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- cipher_suites: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- hex: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |-- compression_methods: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- hex: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |-- extended_master_secret: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- heartbeat: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- next_protocol_negotiation: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- ocsp_stapling: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- random: string (nullable = true)
#  |    |    |    |    |    |    |    |-- sct_enabled: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- scts: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- secure_renegotiation: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- server_name: string (nullable = true)
#  |    |    |    |    |    |    |    |-- signature_and_hashes: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- hash_algorithm: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- signature_algorithm: string (nullable = true)
#  |    |    |    |    |    |    |    |-- supported_curves: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- hex: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |-- supported_point_formats: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- hex: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |-- ticket: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- version: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |-- client_key_exchange: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- ecdh_params: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- client_private: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- client_public: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- x: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- y: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- curve_id: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |-- rsa_params: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- encrypted_pre_master_secret: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |-- key_material: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- master_secret: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |-- pre_master_secret: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |-- server_certificates: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- certificate: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- parsed: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- extensions: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- authority_info_access: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- issuer_urls: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- ocsp_urls: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- authority_key_id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- basic_constraints: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- is_ca: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- certificate_policies: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- cps: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- user_notice: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- explicit_text: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- crl_distribution_points: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- extended_key_usage: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- client_auth: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- server_auth: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- key_usage: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- certificate_sign: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- crl_sign: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- digital_signature: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- key_encipherment: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- signed_certificate_timestamps: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- log_id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- signature: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- timestamp: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- version: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- subject_alt_name: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- dns_names: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- subject_key_id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- fingerprint_md5: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- fingerprint_sha1: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- fingerprint_sha256: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- issuer: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- common_name: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- country: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- email_address: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- locality: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- organization: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- organizational_unit: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- province: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- issuer_dn: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- names: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- redacted: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- serial_number: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- signature: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- self_signed: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- signature_algorithm: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- oid: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- valid: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- signature_algorithm: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- oid: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- spki_subject_fingerprint: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- subject: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- common_name: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- country: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- email_address: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- jurisdiction_country: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- jurisdiction_locality: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- jurisdiction_province: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- locality: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- organization: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- organizational_unit: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- postal_code: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- province: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- serial_number: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- street_address: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- subject_dn: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- subject_key_info: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- fingerprint_sha256: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- key_algorithm: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- rsa_public_key: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- exponent: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- modulus: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- tbs_fingerprint: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- tbs_noct_fingerprint: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- unknown_extensions: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- critical: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- validation_level: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- validity: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- version: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- raw: string (nullable = true)
#  |    |    |    |    |    |    |    |-- chain: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- parsed: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- extensions: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- authority_info_access: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- issuer_urls: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- ocsp_urls: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- authority_key_id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- basic_constraints: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- is_ca: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- max_path_len: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- certificate_policies: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |-- cps: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- crl_distribution_points: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- extended_key_usage: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- client_auth: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- server_auth: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- key_usage: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- certificate_sign: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- crl_sign: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- digital_signature: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- subject_key_id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- fingerprint_md5: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- fingerprint_sha1: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- fingerprint_sha256: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- issuer: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- common_name: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- country: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- locality: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- organization: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- organizational_unit: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- province: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- issuer_dn: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- redacted: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- serial_number: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- signature: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- self_signed: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- signature_algorithm: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- oid: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- valid: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- signature_algorithm: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- oid: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- spki_subject_fingerprint: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- subject: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- common_name: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- country: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- locality: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- organization: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- organizational_unit: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- province: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- subject_dn: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- subject_key_info: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- fingerprint_sha256: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- key_algorithm: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- rsa_public_key: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- exponent: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- modulus: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- tbs_fingerprint: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- tbs_noct_fingerprint: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- validation_level: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- validity: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- version: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- raw: string (nullable = true)
#  |    |    |    |    |    |    |    |-- validation: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- browser_error: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- browser_trusted: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |-- matches_domain: boolean (nullable = true)
#  |    |    |    |    |    |    |-- server_finished: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- verify_data: string (nullable = true)
#  |    |    |    |    |    |    |-- server_hello: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- cipher_suite: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- hex: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |-- compression_method: long (nullable = true)
#  |    |    |    |    |    |    |    |-- extended_master_secret: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- heartbeat: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- ocsp_stapling: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- random: string (nullable = true)
#  |    |    |    |    |    |    |    |-- secure_renegotiation: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- session_id: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ticket: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- version: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |-- server_key_exchange: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- digest: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ecdh_params: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- curve_id: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- server_public: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- x: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- y: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |-- signature: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- raw: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- signature_and_hash_type: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- hash_algorithm: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- signature_algorithm: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- tls_version: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- valid: boolean (nullable = true)
#  |    |    |    |    |    |-- url: struct (nullable = true)
#  |    |    |    |    |    |    |-- host: string (nullable = true)
#  |    |    |    |    |    |    |-- path: string (nullable = true)
#  |    |    |    |    |    |    |-- raw_query: string (nullable = true)
#  |    |    |    |    |    |    |-- scheme: string (nullable = true)
#  |    |    |    |    |-- status_code: long (nullable = true)
#  |    |    |    |    |-- status_line: string (nullable = true)
#  |    |    |    |    |-- transfer_encoding: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- response: struct (nullable = true)
#  |    |    |    |-- body: string (nullable = true)
#  |    |    |    |-- body_sha256: string (nullable = true)
#  |    |    |    |-- content_length: long (nullable = true)
#  |    |    |    |-- headers: struct (nullable = true)
#  |    |    |    |    |-- accept_ranges: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- access_control_allow_origin: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- age: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- allow: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- alt_svc: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- cache_control: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- connection: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- content_encoding: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- content_language: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- content_length: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- content_location: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- content_range: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- content_security_policy: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- content_type: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- expires: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- last_modified: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- link: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- location: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- p3p: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- pragma: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- proxy_agent: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- proxy_authenticate: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- refresh: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- retry_after: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- server: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- set_cookie: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- status: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- strict_transport_security: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- unknown: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- key: string (nullable = true)
#  |    |    |    |    |    |    |-- value: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- upgrade: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- vary: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- via: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- www_authenticate: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- x_content_security_policy: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- x_content_type_options: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- x_frame_options: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- x_powered_by: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- x_ua_compatible: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- x_webkit_csp: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- x_xss_protection: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- protocol: struct (nullable = true)
#  |    |    |    |    |-- major: long (nullable = true)
#  |    |    |    |    |-- minor: long (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- request: struct (nullable = true)
#  |    |    |    |    |-- headers: struct (nullable = true)
#  |    |    |    |    |    |-- referer: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- unknown: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- key: string (nullable = true)
#  |    |    |    |    |    |    |    |-- value: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- host: string (nullable = true)
#  |    |    |    |    |-- method: string (nullable = true)
#  |    |    |    |    |-- tls_handshake: struct (nullable = true)
#  |    |    |    |    |    |-- client_finished: struct (nullable = true)
#  |    |    |    |    |    |    |-- verify_data: string (nullable = true)
#  |    |    |    |    |    |-- client_hello: struct (nullable = true)
#  |    |    |    |    |    |    |-- cipher_suites: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- hex: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |-- compression_methods: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- hex: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |-- extended_master_secret: boolean (nullable = true)
#  |    |    |    |    |    |    |-- heartbeat: boolean (nullable = true)
#  |    |    |    |    |    |    |-- next_protocol_negotiation: boolean (nullable = true)
#  |    |    |    |    |    |    |-- ocsp_stapling: boolean (nullable = true)
#  |    |    |    |    |    |    |-- random: string (nullable = true)
#  |    |    |    |    |    |    |-- sct_enabled: boolean (nullable = true)
#  |    |    |    |    |    |    |-- scts: boolean (nullable = true)
#  |    |    |    |    |    |    |-- secure_renegotiation: boolean (nullable = true)
#  |    |    |    |    |    |    |-- server_name: string (nullable = true)
#  |    |    |    |    |    |    |-- signature_and_hashes: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- hash_algorithm: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- signature_algorithm: string (nullable = true)
#  |    |    |    |    |    |    |-- supported_curves: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- hex: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |-- supported_point_formats: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- hex: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |-- ticket: boolean (nullable = true)
#  |    |    |    |    |    |    |-- version: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |-- client_key_exchange: struct (nullable = true)
#  |    |    |    |    |    |    |-- ecdh_params: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- client_private: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |-- client_public: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- x: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- y: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |-- curve_id: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |-- rsa_params: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- encrypted_pre_master_secret: string (nullable = true)
#  |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |-- key_material: struct (nullable = true)
#  |    |    |    |    |    |    |-- master_secret: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |-- pre_master_secret: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |-- server_certificates: struct (nullable = true)
#  |    |    |    |    |    |    |-- certificate: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- parsed: struct (nullable = true)
# ...
#  |    |    |    |    |    |    |    |    |    |-- organization: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- organizational_unit: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- postal_code: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- province: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- serial_number: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- street_address: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- subject_dn: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- subject_key_info: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- fingerprint_sha256: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- key_algorithm: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- rsa_public_key: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- exponent: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- modulus: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- tbs_fingerprint: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- tbs_noct_fingerprint: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- unknown_extensions: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- critical: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- validation_level: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- validity: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- version: long (nullable = true)
#  |    |    |    |    |    |    |    |-- raw: string (nullable = true)
#  |    |    |    |    |    |    |-- chain: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- parsed: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- extensions: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- authority_info_access: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- issuer_urls: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- ocsp_urls: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- authority_key_id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- basic_constraints: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- is_ca: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- max_path_len: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- certificate_policies: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- cps: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- crl_distribution_points: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- extended_key_usage: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- client_auth: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- server_auth: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- key_usage: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- certificate_sign: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- crl_sign: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- digital_signature: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- subject_key_id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- fingerprint_md5: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- fingerprint_sha1: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- fingerprint_sha256: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- issuer: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- common_name: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- country: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- email_address: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- locality: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- organization: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- organizational_unit: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- province: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- issuer_dn: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- redacted: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- serial_number: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- signature: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- self_signed: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- signature_algorithm: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- oid: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- valid: boolean (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- signature_algorithm: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- oid: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- spki_subject_fingerprint: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- subject: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- common_name: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- country: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- email_address: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- locality: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- organization: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- organizational_unit: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- province: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- subject_dn: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- subject_key_info: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- fingerprint_sha256: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- key_algorithm: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- rsa_public_key: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- exponent: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- modulus: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- tbs_fingerprint: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- tbs_noct_fingerprint: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- validation_level: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- validity: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- version: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- raw: string (nullable = true)
#  |    |    |    |    |    |    |-- validation: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- browser_error: string (nullable = true)
#  |    |    |    |    |    |    |    |-- browser_trusted: boolean (nullable = true)
#  |    |    |    |    |    |    |    |-- matches_domain: boolean (nullable = true)
#  |    |    |    |    |    |-- server_finished: struct (nullable = true)
#  |    |    |    |    |    |    |-- verify_data: string (nullable = true)
#  |    |    |    |    |    |-- server_hello: struct (nullable = true)
#  |    |    |    |    |    |    |-- cipher_suite: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- hex: string (nullable = true)
#  |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |-- compression_method: long (nullable = true)
#  |    |    |    |    |    |    |-- extended_master_secret: boolean (nullable = true)
#  |    |    |    |    |    |    |-- heartbeat: boolean (nullable = true)
#  |    |    |    |    |    |    |-- ocsp_stapling: boolean (nullable = true)
#  |    |    |    |    |    |    |-- random: string (nullable = true)
#  |    |    |    |    |    |    |-- secure_renegotiation: boolean (nullable = true)
#  |    |    |    |    |    |    |-- session_id: string (nullable = true)
#  |    |    |    |    |    |    |-- ticket: boolean (nullable = true)
#  |    |    |    |    |    |    |-- version: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |-- server_key_exchange: struct (nullable = true)
#  |    |    |    |    |    |    |-- digest: string (nullable = true)
#  |    |    |    |    |    |    |-- ecdh_params: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- curve_id: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |-- server_public: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- x: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- y: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- length: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |    |    |-- signature: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- raw: string (nullable = true)
#  |    |    |    |    |    |    |    |-- signature_and_hash_type: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- hash_algorithm: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- signature_algorithm: string (nullable = true)
#  |    |    |    |    |    |    |    |-- tls_version: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- valid: boolean (nullable = true)
#  |    |    |    |    |-- url: struct (nullable = true)
#  |    |    |    |    |    |-- fragment: string (nullable = true)
#  |    |    |    |    |    |-- host: string (nullable = true)
#  |    |    |    |    |    |-- path: string (nullable = true)
#  |    |    |    |    |    |-- raw_query: string (nullable = true)
#  |    |    |    |    |    |-- scheme: string (nullable = true)
#  |    |    |    |-- status_code: long (nullable = true)
#  |    |    |    |-- status_line: string (nullable = true)
#  |    |    |    |-- transfer_encoding: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |-- error: string (nullable = true)
#  |-- ip: string (nullable = true)
#  |-- timestamp: string (nullable = true)

# %%
zgrab.select("ip").show()
# Out:
# +---------------+
# |             ip|
# +---------------+
# | 172.65.100.108|
# | 192.230.66.113|
# |  159.65.233.69|
# | 168.255.128.19|
# | 185.162.171.15|
# | 31.201.254.208|
# |  151.40.76.245|
# |  112.72.33.128|
# | 218.145.166.91|
# |   67.222.68.11|
# |   45.60.107.95|
# | 118.169.10.116|
# |   45.121.57.70|
# |  45.195.160.26|
# |115.131.234.198|
# |115.128.144.139|
# | 68.171.217.103|
# |  123.60.36.156|
# |    119.32.58.2|
# |  168.255.58.46|
# +---------------+
# only showing top 20 rows
