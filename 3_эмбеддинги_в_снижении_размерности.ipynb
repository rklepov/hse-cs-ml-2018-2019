# %% [markdown]
# <a href="https://colab.research.google.com/github/oserikov/data-science-nlp/blob/master/3_%D1%8D%D0%BC%D0%B1%D0%B5%D0%B4%D0%B4%D0%B8%D0%BD%D0%B3%D0%B8_%D0%B2_%D1%81%D0%BD%D0%B8%D0%B6%D0%B5%D0%BD%D0%B8%D0%B8_%D1%80%D0%B0%D0%B7%D0%BC%D0%B5%D1%80%D0%BD%D0%BE%D1%81%D1%82%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/oserikov/data-science-nlp/master/data/rus_stopwords.txt
# !wget https://raw.githubusercontent.com/oserikov/data-science-nlp/master/data/polkrug_lem.txt
# !wget https://rusvectores.org/static/models/news_upos_cbow_300_2_2017.bin.gz
# !gunzip news_upos_cbow_300_2_2017.bin.gz
# Out:
# --2019-12-14 09:14:22--  https://raw.githubusercontent.com/oserikov/data-science-nlp/master/data/rus_stopwords.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4786 (4.7K) [text/plain]
# Saving to: ‘rus_stopwords.txt’
#
# rus_stopwords.txt   100%[===================>]   4.67K  --.-KB/s    in 0s
#
# 2019-12-14 09:14:22 (64.1 MB/s) - ‘rus_stopwords.txt’ saved [4786/4786]
#
# --2019-12-14 09:14:23--  https://raw.githubusercontent.com/oserikov/data-science-nlp/master/data/polkrug_lem.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18309964 (17M) [text/plain]
# Saving to: ‘polkrug_lem.txt’
#
# polkrug_lem.txt     100%[===================>]  17.46M  --.-KB/s    in 0.1s
#
# 2019-12-14 09:14:24 (183 MB/s) - ‘polkrug_lem.txt’ saved [18309964/18309964]
#
# --2019-12-14 09:14:25--  https://rusvectores.org/static/models/news_upos_cbow_300_2_2017.bin.gz
# Resolving rusvectores.org (rusvectores.org)... 116.203.104.23
# Connecting to rusvectores.org (rusvectores.org)|116.203.104.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 140310878 (134M) [application/x-gzip]
# Saving to: ‘news_upos_cbow_300_2_2017.bin.gz’
#
# news_upos_cbow_300_ 100%[===================>] 133.81M  20.4MB/s    in 8.0s
#
# 2019-12-14 09:14:34 (16.6 MB/s) - ‘news_upos_cbow_300_2_2017.bin.gz’ saved [140310878/140310878]

# %%
# !pip install pymorphy2
# Out:
# Collecting pymorphy2
#   Downloading https://files.pythonhosted.org/packages/a3/33/fff9675c68b5f6c63ec8c6e6ff57827dda28a1fa5b2c2d727dffff92dd47/pymorphy2-0.8-py2.py3-none-any.whl (46kB)
#      |████████████████████████████████| 51kB 2.5MB/s
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.6/dist-packages (from pymorphy2) (0.6.2)
# Collecting dawg-python>=0.7
#   Downloading https://files.pythonhosted.org/packages/6a/84/ff1ce2071d4c650ec85745766c0047ccc3b5036f1d03559fd46bb38b5eeb/DAWG_Python-0.7.2-py2.py3-none-any.whl
# Collecting pymorphy2-dicts<3.0,>=2.4
#   Downloading https://files.pythonhosted.org/packages/02/51/2465fd4f72328ab50877b54777764d928da8cb15b74e2680fc1bd8cb3173/pymorphy2_dicts-2.4.393442.3710985-py2.py3-none-any.whl (7.1MB)
#      |████████████████████████████████| 7.1MB 9.5MB/s
# Installing collected packages: dawg-python, pymorphy2-dicts, pymorphy2
# Successfully installed dawg-python-0.7.2 pymorphy2-0.8 pymorphy2-dicts-2.4.393442.3710985

# %%
import umap
import pymorphy2
import gensim
import numpy as np
from matplotlib import pyplot as plt

# %%
polkrug_texts = [line for line in open('polkrug_lem.txt', 'r', encoding='utf-8')][:10000]
w2v_model = gensim.models.KeyedVectors.load_word2vec_format("news_upos_cbow_300_2_2017.bin", binary=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
words = ['день_NOUN', 'ночь_NOUN', 'человек_NOUN', 'семантика_NOUN', 'студент_NOUN', 'студент_ADJ']


for word in words:
    # есть ли слово в модели? Может быть, и нет
    if word in w2v_model:
        print(word)
        # выдаем 10 ближайших соседей слова:
        print(w2v_model.get_vector(word).shape)
        for i in w2v_model.most_similar(positive=[word], topn=10):
            # слово + коэффициент косинусной близости
            print(i[0], i[1])
        print('\n')
    else:
        # Увы!
        print(word + ' is not present in the model')
# Out:
# день_NOUN
# (300,)
# неделя_NOUN 0.6162657141685486
# выходной_NOUN 0.5152238011360168
# час_NOUN 0.5082833170890808
# месяц_NOUN 0.46219247579574585
# год_NOUN 0.456640362739563
# сутки_NOUN 0.45195528864860535
# минута_NOUN 0.45058226585388184
# полчаса_NOUN 0.44852766394615173
# десятилетие_NOUN 0.4127088189125061
# сельхозярмарка_NOUN 0.4065084755420685
#
#
# ночь_NOUN
# (300,)
# вечер_NOUN 0.6862421035766602
# утро_NOUN 0.639569103717804
# воскресение_NOUN 0.5514307022094727
# суббота_NOUN 0.5508831739425659
# полдень_NOUN 0.5491805672645569
# полночь_NOUN 0.5355546474456787
# пятница_NOUN 0.5045558214187622
# четверг_NOUN 0.4788028597831726
# выходной_NOUN 0.44291260838508606
# сегодня_NOUN 0.4398839473724365
#
#
# человек_NOUN
# (300,)
# ребенок_NOUN 0.6082327365875244
# женщина_NOUN 0.600160539150238
# мужчина_NOUN 0.5729535818099976
# украинец_NOUN 0.5605596899986267
# парень_NOUN 0.49850261211395264
# гражданин_NOUN 0.49450385570526123
# подросток_NOUN 0.49111372232437134
# ребята_NOUN 0.48801931738853455
# иностранец_NOUN 0.4839625358581543
# южноуралец_NOUN 0.48387497663497925
#
#
# семантика_NOUN
# (300,)
# фонетический_ADJ 0.6834204196929932
# существительное_NOUN 0.6769273281097412
# транслитерация_NOUN 0.6474891901016235
# прилагательное_NOUN 0.6367714405059814
# заумный_ADJ 0.6298093199729919
# синтаксис_NOUN 0.6286866664886475
# этимология_NOUN 0.6157766580581665
# атрибуция_NOUN 0.6105079650878906
# числительный_ADJ 0.6093981862068176
# сущностный_ADJ 0.6044572591781616
#
#
# студент_NOUN
# (300,)
# первокурсник_NOUN 0.7250221967697144
# магистрант_NOUN 0.6728711128234863
# аспирант_NOUN 0.6654266119003296
# очник_NOUN 0.6485531330108643
# старшекурсник_NOUN 0.6462636590003967
# заочник_NOUN 0.6360019445419312
# второкурсник_NOUN 0.6333087086677551
# старшеклассник_NOUN 0.6034910678863525
# преподаватель_NOUN 0.5987387299537659
# школьник_NOUN 0.5976052284240723
#
#
# студент_ADJ is not present in the model
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
morph_analyzer =  pymorphy2.MorphAnalyzer()
polkrug_texts_vectorized = []
for text_idx, text in enumerate(polkrug_texts):
    text_vs = []
    for word in text.split():
        pos_tag = morph_analyzer.parse(word)[0].tag.POS
        pos_tagged_word = f"{word}_{pos_tag}"
        if word.isalpha() and pos_tagged_word in w2v_model:
            word_v = w2v_model.get_vector(pos_tagged_word)
            # print(f"found {pos_tagged_word}")
            text_vs.append(word_v)
    if text_vs:
        text_v = np.mean(np.array(text_vs), axis=0)
        polkrug_texts_vectorized.append((text, text_v))
    if text_idx % 100 == 0:
        print(f"processed {str(text_idx)} of {str(len(polkrug_texts))}")

print("calculated all the document vectors")

umap_emb = umap.UMAP()
X_2D_umap = umap_emb.fit_transform([e[1] for e in polkrug_texts_vectorized])

for i in range(2):
    plt.scatter(X_2D_umap[i:,0], X_2D_umap[i:,1])
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# processed 0 of 10000
# processed 100 of 10000
# processed 200 of 10000
# processed 300 of 10000
# processed 400 of 10000
# processed 500 of 10000
# processed 600 of 10000
# processed 700 of 10000
# processed 800 of 10000
# processed 900 of 10000
# processed 1000 of 10000
# processed 1100 of 10000
# processed 1200 of 10000
# processed 1300 of 10000
# processed 1400 of 10000
# processed 1500 of 10000
# processed 1600 of 10000
# processed 1700 of 10000
# processed 1800 of 10000
# processed 1900 of 10000
# processed 2000 of 10000
# processed 2100 of 10000
# processed 2200 of 10000
# processed 2300 of 10000
# processed 2400 of 10000
# processed 2500 of 10000
# processed 2600 of 10000
# processed 2700 of 10000
# processed 2800 of 10000
# processed 2900 of 10000
# processed 3000 of 10000
# processed 3100 of 10000
# processed 3200 of 10000
# processed 3300 of 10000
# processed 3400 of 10000
# processed 3500 of 10000
# processed 3600 of 10000
# processed 3700 of 10000
# processed 3800 of 10000
# processed 3900 of 10000
# processed 4000 of 10000
# processed 4100 of 10000
# processed 4200 of 10000
# processed 4300 of 10000
# processed 4400 of 10000
# processed 4500 of 10000
# processed 4600 of 10000
# processed 4700 of 10000
# processed 4800 of 10000
# processed 4900 of 10000
# processed 5000 of 10000
# processed 5100 of 10000
# processed 5200 of 10000
# processed 5300 of 10000
# processed 5400 of 10000
# processed 5500 of 10000
# processed 5600 of 10000
# processed 5700 of 10000
# processed 5800 of 10000
# processed 5900 of 10000
# processed 6000 of 10000
# processed 6100 of 10000
# processed 6200 of 10000
# processed 6300 of 10000
# processed 6400 of 10000
# processed 6500 of 10000
# processed 6600 of 10000
# processed 6700 of 10000
# processed 6800 of 10000
# processed 6900 of 10000
# processed 7000 of 10000
# processed 7100 of 10000
# processed 7200 of 10000
# processed 7300 of 10000
# processed 7400 of 10000
# processed 7500 of 10000
# processed 7600 of 10000
# processed 7700 of 10000
# processed 7800 of 10000
# processed 7900 of 10000
# processed 8000 of 10000
# processed 8100 of 10000
# processed 8200 of 10000
# processed 8300 of 10000
# processed 8400 of 10000
# processed 8500 of 10000
# processed 8600 of 10000
# processed 8700 of 10000
# processed 8800 of 10000
# processed 8900 of 10000
# processed 9000 of 10000
# processed 9100 of 10000
# processed 9200 of 10000
# processed 9300 of 10000
# processed 9400 of 10000
# processed 9500 of 10000
# processed 9600 of 10000
# processed 9700 of 10000
# processed 9800 of 10000
# processed 9900 of 10000
# calculated all the document vectors

# %%
for text, coords in zip([elem[0] for elem in polkrug_texts_vectorized], X_2D_umap):
    if coords[0] < -10:
        print(text, coords)
# Out:
# нет комментарий
#  [-17.184225  -1.944451]
# нет комментарий
#  [-16.917423   -1.3823324]
# нет комментарий
#  [-17.208023  -0.538872]
# нет комментарий
#  [-16.675713   -1.9202087]
# нет комментарий
#  [-17.26449    -1.0560906]
# нет комментарий
#  [-16.60603    -1.8730552]
# нет комментарий
#  [-16.804514   -1.5253198]
# нет комментарий
#  [-17.902338   -1.1438357]
# нет комментарий
#  [-17.458656   -0.8251676]
# нет комментарий
#  [-16.606764   -1.6498878]
# нет комментарий
#  [-16.750072  -1.398927]
# нет комментарий
#  [-16.687338  -1.86891 ]
# нет комментарий
#  [-17.349606   -1.4202005]
# нет комментарий
#  [-17.51771    -1.2528194]
# нет комментарий
#  [-17.517729   -1.5084624]
# нет комментарий
#  [-16.885906   -1.9970268]
# нет комментарий
#  [-16.648663   -1.3875971]
# нет комментарий
#  [-16.485512   -1.9469277]
# нет комментарий
#  [-17.032822   -1.3818446]
# нет комментарий
#  [-17.178822   -1.9203974]
# нет комментарий
#  [-16.603436   -1.7186636]
# нет комментарий
#  [-17.954313   -1.9320952]
# нет комментарий
#  [-17.521149   -0.7143106]
# нет комментарий
#  [-17.301859   -1.9543171]
# нет комментарий
#  [-17.604809   -1.0707694]
# нет комментарий
#  [-17.451385    -0.66958094]
# нет комментарий
#  [-17.104448   -1.2784626]
# нет комментарий
#  [-16.976765   -1.4264216]
# нет комментарий
#  [-16.64565    -1.4563991]
# нет комментарий
#  [-17.39669     -0.88966346]
# нет комментарий
#  [-17.221191  -1.75854 ]
# нет комментарий
#  [-17.196253   -1.4056234]
# нет комментарий
#  [-17.669893   -1.7061857]
# нет комментарий
#  [-16.605423   -1.9094782]
# нет комментарий
#  [-17.14702    -1.3203497]
# нет комментарий
#  [-16.469282   -1.8857048]
# нет комментарий
#  [-17.443449   -1.3058326]
# нет комментарий
#  [-17.106619   -1.5856336]
# нет комментарий
#  [-17.23967    -0.5415636]
# нет комментарий
#  [-17.152348  -0.895121]
# нет комментарий
#  [-17.551819   -1.5418837]
# нет комментарий
#  [-17.089125   -2.2167022]
# нет комментарий
#  [-17.25606    -1.1429408]
# нет комментарий
#  [-16.698057   -1.9951726]
# нет комментарий
#  [-16.65922    -1.9283049]
# нет комментарий
#  [-17.892208   -1.1998272]
# нет комментарий
#  [-16.601208   -1.5786958]
# нет комментарий
#  [-16.48764    -1.5678997]
# нет комментарий
#  [-17.44014    -1.5540111]
# нет комментарий
#  [-16.69606    -1.3652128]
# нет комментарий
#  [-16.960947   -1.8659536]
# нет комментарий
#  [-17.616875   -1.1205274]
# нет комментарий
#  [-16.850306    -0.83029294]
# нет комментарий
#  [-17.566383   -1.4449471]
# нет комментарий
#  [-17.464003   -1.0623704]
# нет комментарий
#  [-17.877424   -1.1629224]
# нет комментарий
#  [-16.92197    -1.2700008]
# нет комментарий
#  [-17.167593    -0.93318474]
# нет комментарий
#  [-17.339243   -1.2775807]
# нет комментарий
#  [-17.310694   -1.7892317]
# нет комментарий
#  [-17.305117   -2.0129933]
# нет комментарий
#  [-16.457525   -2.0181427]
# нет комментарий
#  [-17.166483  -1.351605]
# нет комментарий
#  [-16.75385    -1.4414817]
# нет комментарий
#  [-17.564959   -0.8523546]
# нет комментарий
#  [-17.083157   -2.1803083]
# нет комментарий
#  [-17.539688   -1.4395592]
# нет комментарий
#  [-17.671091   -1.7821348]
# нет комментарий
#  [-17.334028   -1.3612684]
# нет комментарий
#  [-16.422924   -1.3415607]
# нет комментарий
#  [-16.651756   -1.9061489]
# нет комментарий
#  [-16.759354  -2.347733]
# нет комментарий
#  [-17.047283   -1.3634639]
# нет комментарий
#  [-17.094652  -2.37172 ]
# нет комментарий
#  [-17.395626   -1.5985297]
# нет комментарий
#  [-16.710533   -0.7000724]
# нет комментарий
#  [-16.461933   -1.0175806]
# нет комментарий
#  [-17.497166   -1.8780966]
# нет комментарий
#  [-16.22444    -1.6217939]
# нет комментарий
#  [-17.524696  -1.895657]
# нет комментарий
#  [-17.062386  -1.502017]
# нет комментарий
#  [-16.463697   -1.3427439]
# нет комментарий
#  [-17.065483   -1.3463312]
# нет комментарий
#  [-16.63113    -1.7110038]
# нет комментарий
#  [-16.513271   -1.2779613]
# нет комментарий
#  [-17.098595   -1.5914035]
# нет комментарий
#  [-16.488564    -0.98409796]
# нет комментарий
#  [-17.188354   -1.2670522]
# нет комментарий
#  [-17.208616   -1.2727721]
# нет комментарий
#  [-17.893414    -0.85603887]
# нет комментарий
#  [-16.898619  -2.087792]
# нет комментарий
#  [-17.610493   -1.5370297]
# нет комментарий
#  [-16.301311   -1.5597471]
# нет комментарий
#  [-17.25729    -1.2116646]
# нет комментарий
#  [-17.742393  -1.449049]
# нет комментарий
#  [-17.337807   -0.9832443]
# нет комментарий
#  [-16.482288   -1.5639216]
# нет комментарий
#  [-17.038916   -1.7371103]
# нет комментарий
#  [-16.749039  -2.286352]
# нет комментарий
#  [-16.838902   -1.1754417]
# нет комментарий
#  [-16.926031   -1.2091402]
# нет комментарий
#  [-17.43729    -0.8350626]
# нет комментарий
#  [-16.996675   -1.0756756]
# нет комментарий
#  [-16.976532   -1.4651468]
# нет комментарий
#  [-17.70403    -1.2555531]
# нет комментарий
#  [-17.847197   -1.1712505]
# нет комментарий
#  [-17.02808   -1.829926]
# нет комментарий
#  [-16.727777   -1.3625813]
# нет комментарий
#  [-17.497658    -0.67686045]
# нет комментарий
#  [-17.075716   -1.1751107]
# нет комментарий
#  [-17.347876   -1.3893805]
# нет комментарий
#  [-16.917488   -1.3667717]
# нет комментарий
#  [-17.217855   -0.9888423]
# нет комментарий
#  [-16.272171   -1.6225048]
# нет комментарий
#  [-17.047586   -1.1664159]
# нет комментарий
#  [-17.217518   -2.1074173]
# нет комментарий
#  [-17.012466   -1.4992954]
# нет комментарий
#  [-17.373705    -0.83949846]
# нет комментарий
#  [-17.55609    -1.2469327]
# нет комментарий
#  [-16.902891   -1.6964716]
# нет комментарий
#  [-17.16249   -0.570384]
# нет комментарий
#  [-16.476496   -1.6444819]
# нет комментарий
#  [-16.729105   -0.8671818]
# нет комментарий
#  [-16.596611   -1.9574316]
# нет комментарий
#  [-17.112366  -1.405043]
# нет комментарий
#  [-17.973837   -1.7060771]
# нет комментарий
#  [-17.02948    -1.6585865]
# нет комментарий
#  [-17.577988   -1.6342824]
# нет комментарий
#  [-17.655636  -1.528534]
# нет комментарий
#  [-16.629538   -1.5013413]
# нет комментарий
#  [-17.797026   -1.6878687]
# нет комментарий
#  [-16.91971   -2.039467]
# нет комментарий
#  [-17.262058    -0.52870727]
# нет комментарий
#  [-17.05863   -2.268908]
# нет комментарий
#  [-17.714489   -1.3755525]
# нет комментарий
#  [-17.252295   -1.5980546]
# нет комментарий
#  [-17.793139   -1.4943693]
# нет комментарий
#  [-17.14634    -1.1694734]
# нет комментарий
#  [-17.275887   -1.0733846]
# нет комментарий
#  [-16.724651   -1.0426488]
# нет комментарий
#  [-16.872282   -0.8669809]
# нет комментарий
#  [-17.595715  -1.657885]
# нет комментарий
#  [-16.709398  -1.490852]
# нет комментарий
#  [-17.296331   -1.8989187]
# нет комментарий
#  [-17.305801  -2.053729]
# нет комментарий
#  [-17.22967    -0.9576787]
# нет комментарий
#  [-16.503576  -1.329427]
# нет комментарий
#  [-16.883732   -2.0279822]
# нет комментарий
#  [-17.17981   -1.505608]
# нет комментарий
#  [-16.906712   -1.3234893]
# нет комментарий
#  [-17.872423   -1.5166423]
# нет комментарий
#  [-17.863934   -1.4598917]
# нет комментарий
#  [-17.428421   -1.7266814]
# нет комментарий
#  [-17.504938   -1.1366383]
# нет комментарий
#  [-17.34914   -1.234922]
# нет комментарий
#  [-16.772694   -0.8873754]
# нет комментарий
#  [-17.346712   -1.9284766]
# нет комментарий
#  [-17.260578   -1.5479254]
# нет комментарий
#  [-16.466145   -1.2925625]
# нет комментарий
#  [-16.922688   -1.1001182]
# нет комментарий
#  [-17.148018   -2.2335858]
# нет комментарий
#  [-16.926912   -1.1223844]
# нет комментарий
#  [-16.763775   -2.2755682]
# нет комментарий
#  [-17.901842   -0.8874743]
# нет комментарий
#  [-17.71104    -1.6028585]
# нет комментарий
#  [-17.443073   -1.6898088]
# нет комментарий
#  [-17.806234   -1.5490854]
# нет комментарий
#  [-17.087984   -1.6911042]
# нет комментарий
#  [-16.463648    -0.98180217]
# нет комментарий
#  [-16.938732   -1.6978248]
# нет комментарий
#  [-17.412495  -1.402885]
# нет комментарий
#  [-17.187937   -1.4493797]
# нет комментарий
#  [-17.472857   -1.9959109]
# нет комментарий
#  [-17.252026   -1.5302535]
# нет комментарий
#  [-17.170979   -2.1764235]
# нет комментарий
#  [-17.216192   -1.1288514]
# нет комментарий
#  [-17.46647    -0.6916344]
# нет комментарий
#  [-17.93582    -1.9005721]
# нет комментарий
#  [-16.435072   -1.0277532]
# нет комментарий
#  [-16.74676    -0.7618552]
# нет комментарий
#  [-17.028994  -1.51264 ]
# нет комментарий
#  [-17.219282   -1.0811673]
# нет комментарий
#  [-17.118422   -1.5508072]
# нет комментарий
#  [-16.91411    -1.9805554]
# нет комментарий
#  [-16.943262  -1.218986]
# нет комментарий
#  [-17.05077   -1.811586]
# нет комментарий
#  [-17.548925   -2.2145548]
# нет комментарий
#  [-17.412788   -1.5638003]
# нет комментарий
#  [-16.73576    -1.3637382]
# нет комментарий
#  [-17.485954   -1.9292881]
# нет комментарий
#  [-17.100767   -1.8976601]
# нет комментарий
#  [-17.223701    -0.82344025]
# нет комментарий
#  [-16.591621   -1.4867324]
# нет комментарий
#  [-17.603167   -1.6331444]
# нет комментарий
#  [-17.110126   -2.4011195]
# нет комментарий
#  [-17.907606   -0.9595783]
# нет комментарий
#  [-16.961239   -1.6152904]
# нет комментарий
#  [-17.043514   -2.2245724]
# нет комментарий
#  [-16.960804   -1.6433076]
# нет комментарий
#  [-16.870197   -1.2126393]
# нет комментарий
#  [-16.685343    -0.58178616]
# нет комментарий
#  [-17.168333   -1.6622944]
# нет комментарий
#  [-16.901432   -1.1501889]
# нет комментарий
#  [-17.940832   -1.7885727]
# нет комментарий
#  [-16.404549   -1.3126347]
# нет комментарий
#  [-16.982107   -2.0808954]
# нет комментарий
#  [-16.725273   -0.7783424]
# нет комментарий
#  [-16.757849   -2.2499764]
# нет комментарий
#  [-17.83483    -1.4049078]
# нет комментарий
#  [-16.706995   -1.9658481]
# нет комментарий
#  [-17.137205   -2.3339927]
# нет комментарий
#  [-17.22552     -0.51498157]
# нет комментарий
#  [-17.746782   -2.1624432]
# нет комментарий
#  [-17.133257   -1.4269133]
# нет комментарий
#  [-17.067764   -1.2364459]
# нет комментарий
#  [-17.237865   -1.1499145]
# нет комментарий
#  [-17.546568   -1.7724735]
# нет комментарий
#  [-16.941769   -1.5142498]
# нет комментарий
#  [-16.46017   -2.002758]
# нет комментарий
#  [-17.59909    -1.0766971]
# нет комментарий
#  [-16.730934   -1.3451489]
# нет комментарий
#  [-17.398363    -0.87174416]
# нет комментарий
#  [-17.103596   -1.1129752]
# нет комментарий
#  [-16.46383    -1.3264399]
# нет комментарий
#  [-17.922283   -1.7043617]
# нет комментарий
#  [-16.706623   -0.6876254]
# нет комментарий
#  [-17.446507  -1.914317]
# нет комментарий
#  [-17.2043     -2.0935032]
# нет комментарий
#  [-16.583332   -1.9049451]
# нет комментарий
#  [-16.760077   -1.4363536]
# нет комментарий
#  [-16.76766    -1.4289422]
# нет комментарий
#  [-17.295216   -2.0961869]
# нет комментарий
#  [-16.505411   -1.3218005]
# нет комментарий
#  [-16.736414   -0.8111117]
# нет комментарий
#  [-16.727758   -1.8418847]
# нет комментарий
#  [-16.893082   -1.6704564]
# нет комментарий
#  [-17.323318   -1.2259736]
# нет комментарий
#  [-16.839191   -1.4366599]
# нет комментарий
#  [-17.062819   -0.9846056]
# нет комментарий
#  [-17.09593    -1.7295821]
# нет комментарий
#  [-16.845139   -1.7738221]
# нет комментарий
#  [-17.23618    -2.0571277]
# нет комментарий
#  [-17.625893   -1.6123462]
# нет комментарий
#  [-16.887917    -0.83716285]
# нет комментарий
#  [-17.185068   -1.9498208]
# нет комментарий
#  [-17.49345    -1.9077853]
# нет комментарий
#  [-17.827974  -1.472662]
# нет комментарий
#  [-17.346708   -1.1857435]
# нет комментарий
#  [-17.20019    -2.1300936]
# нет комментарий
#  [-16.216875   -1.6087912]
# нет комментарий
#  [-17.145292   -1.0281163]
# нет комментарий
#  [-17.587177    -0.98280895]
# нет комментарий
#  [-16.789516  -1.008921]
# нет комментарий
#  [-17.076735   -1.9595122]
# нет комментарий
#  [-17.218021   -0.9349884]
# нет комментарий
#  [-17.05033    -1.4414121]
# нет комментарий
#  [-17.72864    -2.1340296]
# нет комментарий
#  [-17.041441    -0.73726267]
# нет комментарий
#  [-16.505781   -1.2796761]
# нет комментарий
#  [-16.59683    -1.9008467]
# нет комментарий
#  [-16.639425   -1.5882769]
# нет комментарий
#  [-17.532118   -1.9078786]
# нет комментарий
#  [-17.090324   -0.7550489]
# нет комментарий
#  [-17.548744   -1.4276619]
# нет комментарий
#  [-17.117018   -0.8786589]
# нет комментарий
#  [-17.24982    -1.1887367]
# нет комментарий
#  [-17.56132   -2.204255]
# нет комментарий
#  [-17.015984   -1.4578433]
# нет комментарий
#  [-17.001736   -1.9530288]
# нет комментарий
#  [-16.698498    -0.79782873]
# нет комментарий
#  [-17.50147    -1.3976506]
# нет комментарий
#  [-17.213125    -0.52879256]
# нет комментарий
#  [-17.22539    -2.0562277]
# нет комментарий
#  [-17.145784   -1.7211431]
# нет комментарий
#  [-17.057281   -1.1747677]
# нет комментарий
#  [-17.438643   -1.0256661]
# нет комментарий
#  [-16.901522  -1.403514]
# нет комментарий
#  [-17.325489   -1.3187848]
# нет комментарий
#  [-17.668835   -1.1791364]
# нет комментарий
#  [-17.51473    -1.9179002]
# нет комментарий
#  [-16.959188   -1.5634961]
# нет комментарий
#  [-17.07416    -1.8741325]
# нет комментарий
#  [-17.091303  -2.091959]
# нет комментарий
#  [-17.832253   -1.4631541]
# нет комментарий
#  [-17.677761   -2.0286627]
# нет комментарий
#  [-17.068983   -2.3872323]
# нет комментарий
#  [-16.451267   -1.9739496]
# нет комментарий
#  [-17.188517   -1.7929026]
# нет комментарий
#  [-16.486315   -1.0133562]
# нет комментарий
#  [-16.837418   -1.2197274]
# нет комментарий
#  [-17.019567    -0.75608987]
# нет комментарий
#  [-17.261036   -1.5136107]
# нет комментарий
#  [-17.613153   -1.4754316]
# нет комментарий
#  [-17.304588   -2.4241614]
# нет комментарий
#  [-17.031757   -1.1538575]
# нет комментарий
#  [-17.082802   -2.2276766]
# нет комментарий
#  [-16.757683   -1.9699553]
# нет комментарий
#  [-17.426022   -1.1298156]
# нет комментарий
#  [-16.855743  -0.791074]
# нет комментарий
#  [-17.566835   -1.3598459]
# нет комментарий
#  [-17.166035    -0.98971856]
# нет комментарий
#  [-17.84551    -1.3549892]
# нет комментарий
#  [-17.709576    -0.82009226]
# нет комментарий
#  [-17.309752    -0.84646714]
# нет комментарий
#  [-17.850224   -1.1965988]
# нет комментарий
#  [-17.191021  -1.414805]
# нет комментарий
#  [-16.741917   -1.1012695]
# нет комментарий
#  [-17.01796   -1.262822]
# нет комментарий
#  [-17.002014   -1.1378251]
# нет комментарий
#  [-17.366999   -1.4777507]
# нет комментарий
#  [-17.276447   -1.9651272]
# нет комментарий
#  [-16.650648   -1.6466742]
# нет комментарий
#  [-17.444288  -1.3889  ]
# нет комментарий
#  [-17.505014   -1.5929451]
# нет комментарий
#  [-17.513617   -1.3837187]
# нет комментарий
#  [-17.708218   -0.8412552]
# нет комментарий
#  [-16.49263    -1.2707937]
# нет комментарий
#  [-17.244123   -1.4669387]
# нет комментарий
#  [-17.511328   -1.1120843]
# нет комментарий
#  [-17.405956   -1.7476501]
# нет комментарий
#  [-17.288218   -0.9592211]
# нет комментарий
#  [-17.912033   -0.8562805]
# нет комментарий
#  [-17.611038   -1.5097193]
# нет комментарий
#  [-17.053701   -0.7528721]
# нет комментарий
#  [-17.255459   -1.6206661]
# нет комментарий
#  [-17.525433   -2.2158172]
# нет комментарий
#  [-16.475138   -1.6974775]
# нет комментарий
#  [-17.623816   -1.4498886]
# нет комментарий
#  [-16.258623   -1.6327659]
# нет комментарий
#  [-16.968885  -2.137069]
# нет комментарий
#  [-17.918083   -0.8936571]
# нет комментарий
#  [-16.476238   -1.9880083]
# нет комментарий
#  [-17.57897    -1.4008238]
# нет комментарий
#  [-17.003937   -1.4876633]
# нет комментарий
#  [-16.944492   -0.8188666]
# нет комментарий
#  [-17.072989  -1.111501]
# нет комментарий
#  [-17.010073   -1.8353301]
# нет комментарий
#  [-16.68116    -1.9126298]
# нет комментарий
#  [-16.953909   -1.7227739]
# нет комментарий
#  [-16.74777    -2.3016763]
# нет комментарий
#  [-17.561398  -1.942212]
# нет комментарий
#  [-16.737709   -0.6453152]
# нет комментарий
#  [-16.420992   -1.2498553]
# нет комментарий
#  [-17.90763   -0.888843]
# нет комментарий
#  [-16.714075   -1.0346906]
# нет комментарий
#  [-16.453497   -1.3634568]
# нет комментарий
#  [-17.58967    -2.1796453]
# нет комментарий
#  [-17.624342   -1.8485327]
# нет комментарий
#  [-16.921278   -1.3610247]
# нет комментарий
#  [-16.605795   -1.9114234]
# нет комментарий
#  [-16.506832   -1.6603812]
# нет комментарий
#  [-17.505472   -1.8100903]
# нет комментарий
#  [-17.100107   -2.1802495]
# нет комментарий
#  [-17.104351   -1.0528531]
# нет комментарий
#  [-16.60726    -1.4691013]
# нет комментарий
#  [-16.867022   -1.2689797]
# нет комментарий
#  [-16.484318   -1.0264794]
# нет комментарий
#  [-17.50851    -2.2466724]
# нет комментарий
#  [-16.876715   -1.5568885]
# нет комментарий
#  [-16.230724   -1.6418177]
# нет комментарий
#  [-17.233145    -0.51368326]
# нет комментарий
#  [-17.6808     -1.1877341]
# нет комментарий
#  [-17.225086  -1.939862]
# нет комментарий
#  [-17.727732   -1.2036529]
# нет комментарий
#  [-17.365713    -0.80342233]
# нет комментарий
#  [-17.02833    -1.0943941]
# нет комментарий
#  [-17.078503   -2.3843412]
# нет комментарий
#  [-16.750193    -0.82081324]
# нет комментарий
#  [-16.764853   -0.8515065]
# нет комментарий
#  [-16.778341   -0.9977192]
# нет комментарий
#  [-17.960556   -1.8676981]
# нет комментарий
#  [-17.154858   -0.9738386]
# нет комментарий
#  [-17.176727  -1.674086]
# нет комментарий
#  [-17.97356    -1.7082595]
# нет комментарий
#  [-17.456295    -0.69622767]
# нет комментарий
#  [-17.427414   -1.1412151]
# нет комментарий
#  [-17.36451    -2.0952022]
# нет комментарий
#  [-16.79496   -1.382884]
# нет комментарий
#  [-17.378279   -1.4293636]
# нет комментарий
#  [-17.323473   -1.4618137]
# нет комментарий
#  [-17.493343   -1.1335407]
# нет комментарий
#  [-17.321074   -1.6157634]
# нет комментарий
#  [-17.005318   -2.0630362]
# нет комментарий
#  [-17.48491    -1.3120861]
# нет комментарий
#  [-16.956572  -2.03201 ]
# нет комментарий
#  [-16.93065  -1.0395 ]
# нет комментарий
#  [-16.628618   -1.2969894]
# нет комментарий
#  [-17.57892    -1.4965093]
# нет комментарий
#  [-17.079039   -2.4048393]
# нет комментарий
#  [-17.548708   -1.7654886]
# нет комментарий
#  [-17.159245   -1.7834506]
# нет комментарий
#  [-16.885397    -0.82601917]
# нет комментарий
#  [-16.914604   -1.2212155]
# нет комментарий
#  [-16.209002   -1.6111621]
# нет комментарий
#  [-16.712498   -1.4537994]
# нет комментарий
#  [-17.047478  -2.093294]
# нет комментарий
#  [-17.090218   -2.3447561]
# нет комментарий
#  [-16.76724     -0.80321354]
# нет комментарий
#  [-17.309471   -1.7889607]
# нет комментарий
#  [-17.343708   -0.8416208]
# нет комментарий
#  [-17.752386   -2.1069455]
# нет комментарий
#  [-17.947563   -1.8460984]
# нет комментарий
#  [-16.421932  -1.356738]
# нет комментарий
#  [-17.121416   -1.8282757]
# нет комментарий
#  [-17.69524    -2.0935078]
# нет комментарий
#  [-16.88478    -1.5558192]
# нет комментарий
#  [-17.510475   -1.3428394]
# нет комментарий
#  [-17.368975   -1.0597028]
# нет комментарий
#  [-17.207327   -1.7534642]
# нет комментарий
#  [-17.414898   -1.3991371]
# нет комментарий
#  [-16.798595   -1.6429942]
# нет комментарий
#  [-17.795069   -1.6924163]
# нет комментарий
#  [-16.695246   -0.6031868]
# нет комментарий
#  [-16.24033    -1.6255273]
# нет комментарий
#  [-16.885057   -2.0409405]
# нет комментарий
#  [-16.66895    -1.9700458]
# нет комментарий
#  [-16.83763    -1.6673996]
# нет комментарий
#  [-16.4239    -2.013745]
# нет комментарий
#  [-17.303576   -1.7830526]
# нет комментарий
#  [-17.089977   -2.2045076]
# нет комментарий
#  [-17.319284   -1.8071609]
# нет комментарий
#  [-16.716011    -0.97402734]
# нет комментарий
#  [-17.851116  -0.846479]
# нет комментарий
#  [-17.266842  -0.855279]
# нет комментарий
#  [-17.55241    -1.3842217]
# нет комментарий
#  [-16.74969   -1.939471]
# нет комментарий
#  [-17.0278     -1.4360151]
# нет комментарий
#  [-16.881233   -1.5210618]
# нет комментарий
#  [-17.021002  -1.242289]
# нет комментарий
#  [-17.625334   -1.4834353]
# нет комментарий
#  [-16.843403   -0.9072759]
# нет комментарий
#  [-17.68693    -2.0705042]
# нет комментарий
#  [-17.805742   -1.7922206]
# нет комментарий
#  [-16.977615   -1.8062476]
# нет комментарий
#  [-17.721916   -2.1243808]
# нет комментарий
#  [-17.253819   -1.2121034]
# нет комментарий
#  [-17.33421    -2.3708246]
# нет комментарий
#  [-16.944622   -1.6794388]
# нет комментарий
#  [-16.538324   -1.1995938]
# нет комментарий
#  [-17.057875   -1.3397099]
# нет комментарий
#  [-17.084723   -1.3006215]
# нет комментарий
#  [-17.960066   -1.8784266]
# нет комментарий
#  [-17.577084   -2.1981916]
# нет комментарий
#  [-17.614859  -1.852525]
# нет комментарий
#  [-16.747158  -2.270367]
# нет комментарий
#  [-17.551926   -1.3501953]
# нет комментарий
#  [-17.263279    -0.88374454]
# нет комментарий
#  [-16.471012  -1.322586]
# нет комментарий
#  [-17.489697   -0.6576519]
# нет комментарий
#  [-16.446001   -1.3489906]
# нет комментарий
#  [-16.814102  -1.830599]
# нет комментарий
#  [-16.521347   -1.3163953]
# нет комментарий
#  [-16.485588   -1.6545273]
# нет комментарий
#  [-17.074696   -1.3992264]
# нет комментарий
#  [-16.466782   -1.6823627]
# нет комментарий
#  [-16.768702  -1.476756]
# нет комментарий
#  [-17.165085   -1.0228463]
# нет комментарий
#  [-17.215773   -1.4357032]
# нет комментарий
#  [-16.676184   -1.9254789]
# нет комментарий
#  [-17.633383   -1.0252568]
# нет комментарий
#  [-17.056818   -1.0143938]
# нет комментарий
#  [-16.6532     -1.5244462]
# нет комментарий
#  [-16.552979   -1.3264123]
# нет комментарий
#  [-17.443684   -1.5700482]
# нет комментарий
#  [-17.758259  -2.13396 ]
# нет комментарий
#  [-17.18491    -1.7998178]
# нет комментарий
#  [-17.155571  -2.232298]
# нет комментарий
#  [-16.478237   -1.0089247]
# нет комментарий
#  [-17.679806    -0.76545066]
# нет комментарий
#  [-16.70688   -0.663914]
# нет комментарий
#  [-17.311712   -1.7896613]
# нет комментарий
#  [-16.628887   -1.4581497]
# нет комментарий
#  [-17.529932  -1.967767]
# нет комментарий
#  [-17.878069   -1.5519931]
# нет комментарий
#  [-16.704512   -1.0889735]
# нет комментарий
#  [-16.721973  -1.458465]
# нет комментарий
#  [-17.100452   -2.3760495]
# нет комментарий
#  [-17.804039  -1.406159]
# нет комментарий
#  [-17.921932   -1.6984726]
# нет комментарий
#  [-16.838814   -1.1722356]
# нет комментарий
#  [-17.515278   -1.8224983]
# нет комментарий
#  [-17.911386   -1.1431041]
# нет комментарий
#  [-17.32367    -2.3606012]
# нет комментарий
#  [-17.79611    -1.7443961]
# нет комментарий
#  [-16.704264   -1.0838926]
# нет комментарий
#  [-17.300041   -1.7218661]
# нет комментарий
#  [-17.043098   -1.7976825]
# нет комментарий
#  [-17.162584   -1.2093476]
# нет комментарий
#  [-16.89928    -0.7942283]
# нет комментарий
#  [-17.074064   -2.1554196]
# нет комментарий
#  [-17.280563   -1.7866112]
# нет комментарий
#  [-16.482327   -1.6870489]
# нет комментарий
#  [-17.231436   -1.6195227]
# нет комментарий
#  [-16.628738   -1.4913944]
# нет комментарий
#  [-17.154598   -1.7618409]
# нет комментарий
#  [-16.74382    -1.5007123]
# нет комментарий
#  [-17.34749    -1.7043833]
# нет комментарий
#  [-17.929226   -0.9062545]
# нет комментарий
#  [-16.883257   -0.8441561]
# нет комментарий
#  [-17.77708    -1.6944944]
# нет комментарий
#  [-17.229086   -0.9409049]
# нет комментарий
#  [-17.31149    -2.4432163]
# нет комментарий
#  [-17.70867    -2.1320882]
# нет комментарий
#  [-16.424755   -1.2976906]
# нет комментарий
#  [-16.504057   -1.2701492]
# нет комментарий
#  [-16.491009   -0.9927256]
# нет комментарий
#  [-17.305214   -2.4107664]
# нет комментарий
#  [-16.914392   -1.6403648]
# нет комментарий
#  [-16.89861    -1.6331692]
# нет комментарий
#  [-16.46538    -1.6779511]
# нет комментарий
#  [-17.887808    -0.86527854]
# нет комментарий
#  [-17.676903    -0.85231686]
# нет комментарий
#  [-17.258926   -1.6458558]
# нет комментарий
#  [-17.594217   -1.9454616]
# нет комментарий
#  [-17.155909   -1.3457545]
# нет комментарий
#  [-16.450727   -1.7083471]
# нет комментарий
#  [-17.180687  -0.850934]
# нет комментарий
#  [-17.345142   -2.0142217]
# нет комментарий
#  [-16.939125   -1.9107195]
# нет комментарий
#  [-16.499752   -1.9248056]
# нет комментарий
#  [-16.715761   -0.6513126]
# нет комментарий
#  [-17.174728   -1.5091463]
# нет комментарий
#  [-17.328115   -1.7182173]
# нет комментарий
#  [-17.311628   -1.4692937]
# нет комментарий
#  [-16.546894   -1.6470059]
# нет комментарий
#  [-17.371574   -1.3232236]
# нет комментарий
#  [-17.931738   -1.1481777]
# нет комментарий
#  [-17.073202   -0.6812012]
# нет комментарий
#  [-17.292631  -1.183955]
# нет комментарий
#  [-17.654196   -1.2689259]
# нет комментарий
#  [-17.055609  -1.353206]
# нет комментарий
#  [-17.22482    -1.8936415]
# нет комментарий
#  [-16.777561   -1.0056039]
# нет комментарий
#  [-17.568975   -1.4325565]
# нет комментарий
#  [-16.705578   -1.0493284]
# нет комментарий
#  [-17.120474   -1.1954911]
# нет комментарий
#  [-16.2419     -1.6068575]
# нет комментарий
#  [-17.881657    -0.86699003]
# нет комментарий
#  [-17.079058    -0.71557295]
# нет комментарий
#  [-17.789808   -1.6927125]
# нет комментарий
#  [-16.918892   -1.5519229]
# нет комментарий
#  [-16.52599    -1.9904382]
# нет комментарий
#  [-17.27085    -1.8600677]
# нет комментарий
#  [-17.414051    -0.83354485]
# нет комментарий
#  [-17.844309   -1.5456145]
# нет комментарий
#  [-17.123226   -1.7972885]
# нет комментарий
#  [-17.158737   -1.6699352]
# нет комментарий
#  [-17.42398    -0.8461757]
# нет комментарий
#  [-16.525398   -1.6555091]
# нет комментарий
#  [-17.940447   -1.8658963]
# нет комментарий
#  [-17.769526   -1.5232273]
# нет комментарий
#  [-17.023209   -1.8579079]
# нет комментарий
#  [-17.894615  -1.699116]
# нет комментарий
#  [-16.988298   -1.2437868]
# нет комментарий
#  [-17.555815   -2.2251658]
# нет комментарий
#  [-17.538702   -1.3383734]
# нет комментарий
#  [-16.240164  -1.612338]
# нет комментарий
#  [-16.681433   -1.5348811]
# нет комментарий
#  [-16.702885   -2.0296464]
# нет комментарий
#  [-17.474657   -1.3868712]
# нет комментарий
#  [-17.118282    -0.70619386]
# нет комментарий
#  [-17.4003     -1.4181716]
# нет комментарий
#  [-16.841818   -1.4922899]
# нет комментарий
#  [-17.748972   -1.7468653]
# нет комментарий
#  [-17.785854   -1.4722315]
# нет комментарий
#  [-17.406483   -1.6336331]
# нет комментарий
#  [-17.40978   -1.075659]
# нет комментарий
#  [-16.68033    -0.6309954]
# нет комментарий
#  [-16.66785    -1.5894996]
# нет комментарий
#  [-16.61242    -1.3802164]
# нет комментарий
#  [-17.347471   -2.4235313]
# нет комментарий
#  [-17.083326   -1.6078672]
# нет комментарий
#  [-17.270302   -1.8368869]
# нет комментарий
#  [-16.90605   -1.208473]
# нет комментарий
#  [-17.018135  -1.336716]
# нет комментарий
#  [-17.45273   -0.720106]
# нет комментарий
#  [-17.126999   -1.4827806]
# нет комментарий
#  [-17.588692  -1.740538]
# нет комментарий
#  [-16.906977   -1.5024877]
# нет комментарий
#  [-17.026155    -0.70942354]
# нет комментарий
#  [-17.342596   -2.3828514]
# нет комментарий
#  [-17.66253    -1.8463773]
# нет комментарий
#  [-17.910894   -1.6680807]
# нет комментарий
#  [-16.679432   -1.8670334]
# нет комментарий
#  [-17.890383   -1.8583884]
# нет комментарий
#  [-17.156317   -2.1771467]
# нет комментарий
#  [-17.476088   -1.8214585]
# нет комментарий
#  [-17.856747   -1.2157428]
# нет комментарий
#  [-17.467184   -1.2691858]
# нет комментарий
#  [-17.912807   -1.1769592]
# нет комментарий
#  [-17.262922   -0.5212737]
# нет комментарий
#  [-16.474285    -0.97367066]
# нет комментарий
#  [-17.67744    -0.8266588]
# нет комментарий
#  [-17.892975   -1.1426842]
# нет комментарий
#  [-17.014101   -1.2110045]
# нет комментарий
#  [-17.387182   -1.1041079]
# нет комментарий
#  [-17.246515    -0.96939373]
# нет комментарий
#  [-16.901917   -2.0362177]
# нет комментарий
#  [-17.216524   -1.8300202]
# нет комментарий
#  [-17.020384  -1.064483]
# нет комментарий
#  [-17.844688   -1.3576918]
# нет комментарий
#  [-16.650944   -1.4977481]
# нет комментарий
#  [-17.284883   -1.9435875]
# нет комментарий
#  [-17.01767    -1.3704358]
# нет комментарий
#  [-16.701618   -1.9822972]
# нет комментарий
#  [-17.931345  -1.717524]
# нет комментарий
#  [-16.957638   -1.7354596]
# нет комментарий
#  [-17.570318   -1.5163692]
# нет комментарий
#  [-16.645699   -1.6438628]
# нет комментарий
#  [-16.765537  -0.88948 ]
# нет комментарий
#  [-16.967686   -2.0924695]
# нет комментарий
#  [-17.211744    -0.95924735]
# нет комментарий
#  [-17.896738   -1.8062462]
# нет комментарий
#  [-17.09111    -2.3968704]
# нет комментарий
#  [-16.69431    -0.6731449]
# нет комментарий
#  [-16.768896    -0.81326413]
# нет комментарий
#  [-16.9564     -1.6749964]
# нет комментарий
#  [-17.251152  -1.49331 ]
# нет комментарий
#  [-17.745476   -1.4550238]
# нет комментарий
#  [-17.208382   -1.5313478]
# нет комментарий
#  [-16.670317   -1.9820187]
# нет комментарий
#  [-17.338402   -1.3202287]
# нет комментарий
#  [-17.72691    -2.1048052]
# нет комментарий
#  [-17.092985  -1.453052]
# нет комментарий
#  [-17.650026   -1.2873864]
# нет комментарий
#  [-17.698023   -1.1016905]
# нет комментарий
#  [-17.191538    -0.88647825]
# нет комментарий
#  [-17.486177   -1.0579734]
# нет комментарий
#  [-16.922691   -2.0135264]
# нет комментарий
#  [-17.736717   -1.7463961]
# нет комментарий
#  [-17.516281   -1.6828629]
# нет комментарий
#  [-16.748209  -2.287363]
# нет комментарий
#  [-16.23115    -1.6056236]
# нет комментарий
#  [-17.094652   -1.3853805]
# нет комментарий
#  [-17.517475    -0.65551233]
# нет комментарий
#  [-17.043406   -2.1433978]
# нет комментарий
#  [-16.9899     -1.4194877]
# нет комментарий
#  [-17.005125   -1.4048764]
# нет комментарий
#  [-16.650229   -1.4280976]
# нет комментарий
#  [-17.103914   -1.3429205]
# нет комментарий
#  [-17.757687   -1.2409048]
# нет комментарий
#  [-17.717413   -2.1109576]
# нет комментарий
#  [-17.301844   -1.2496475]
# нет комментарий
#  [-17.228344   -2.0161583]
# нет комментарий
#  [-17.639982   -1.3967502]
# нет комментарий
#  [-16.51361  -1.95341]
# нет комментарий
#  [-17.5615     -1.3547015]
# нет комментарий
#  [-16.909025   -1.8909655]
# нет комментарий
#  [-16.474009   -1.0318419]
# нет комментарий
#  [-16.49536    -0.9809383]
# нет комментарий
#  [-17.282778   -1.5629412]
# нет комментарий
#  [-17.822542  -1.563807]
# нет комментарий
#  [-17.352835   -1.6574178]
# нет комментарий
#  [-17.426228   -1.7961875]
# нет комментарий
#  [-17.237213   -1.4476739]
# нет комментарий
#  [-17.11068    -1.4749318]
# нет комментарий
#  [-17.56174    -1.3152446]
# нет комментарий
#  [-17.064068   -1.3220025]
# нет комментарий
#  [-17.268896   -2.0930855]
# нет комментарий
#  [-17.767317   -1.7263731]
# нет комментарий
#  [-17.543224  -2.189442]
# нет комментарий
#  [-17.073513   -1.7452587]
# нет комментарий
#  [-16.8763     -1.2899389]
# нет комментарий
#  [-16.720423   -2.2948241]
# нет комментарий
#  [-17.941948   -1.7096618]
# нет комментарий
#  [-16.666065   -1.9711514]
# нет комментарий
#  [-17.156183   -1.6567669]
# нет комментарий
#  [-16.77869    -1.7821912]
# нет комментарий
#  [-17.74328     -0.83875996]
# нет комментарий
#  [-16.979261   -1.0159591]
# нет комментарий
#  [-16.98712    -1.2624841]
# нет комментарий
#  [-16.956133   -0.8763867]
# нет комментарий
#  [-16.69455    -0.6191138]
# нет комментарий
#  [-17.553265   -1.8100041]
# нет комментарий
#  [-16.236776   -1.6127605]
# нет комментарий
#  [-17.55916    -1.7119449]
# нет комментарий
#  [-17.63346    -1.0644777]
# нет комментарий
#  [-16.49315    -1.2760494]
# нет комментарий
#  [-16.888756   -0.8365555]
# нет комментарий
#  [-16.475069   -1.8844231]
# нет комментарий
#  [-17.43603    -1.4879092]
# нет комментарий
#  [-16.83907    -1.9990326]
# нет комментарий
#  [-17.039198   -1.2921375]
# нет комментарий
#  [-17.311234  -2.39964 ]
# нет комментарий
#  [-17.512545   -0.6354592]
# нет комментарий
#  [-17.559256   -1.6997725]
# нет комментарий
#  [-17.237385    -0.57885844]
# нет комментарий
#  [-16.675335   -1.4953134]
# нет комментарий
#  [-16.505753   -0.9905157]
# нет комментарий
#  [-17.089886   -2.1749284]
# нет комментарий
#  [-17.554846  -2.149311]
# нет комментарий
#  [-17.563688   -2.2130854]
# нет комментарий
#  [-17.597385   -1.4893407]
# нет комментарий
#  [-17.609419  -1.953855]
# нет комментарий
#  [-16.989096   -1.1187825]
# нет комментарий
#  [-16.83621    -0.8944664]
# нет комментарий
#  [-17.126057   -1.5437527]
# нет комментарий
#  [-17.368427   -1.9636916]
# нет комментарий
#  [-17.070833   -2.1243632]
# нет комментарий
#  [-17.274673  -1.006157]
# нет комментарий
#  [-17.744738  -1.203175]
# нет комментарий
#  [-17.424719   -1.3120773]
# нет комментарий
#  [-17.705303    -0.83111286]
# нет комментарий
#  [-16.985264   -1.9146601]
# нет комментарий
#  [-17.168394  -1.360233]
# нет комментарий
#  [-16.661633   -1.4821974]
# нет комментарий
#  [-17.504982   -0.6606144]
# нет комментарий
#  [-17.362999   -1.4803354]
# нет комментарий
#  [-16.92989    -1.8977048]
# нет комментарий
#  [-16.461811   -1.2968591]
# нет комментарий
#  [-16.735197   -2.2514453]
# нет комментарий
#  [-16.859869   -1.6758682]
# нет комментарий
#  [-17.066284   -1.8488512]
# нет комментарий
#  [-17.604591   -1.4860439]
# нет комментарий
#  [-16.919594   -1.7318355]
# нет комментарий
#  [-16.593388   -1.6496503]
# нет комментарий
#  [-17.907064   -1.7448205]
# нет комментарий
#  [-17.109154   -1.1184844]
# нет комментарий
#  [-16.75996    -0.9966242]
# нет комментарий
#  [-17.13023   -1.548444]
# нет комментарий
#  [-17.438614  -1.046737]
# нет комментарий
#  [-17.412659   -1.1071388]
# нет комментарий
#  [-16.975315   -1.5506935]
# нет комментарий
#  [-17.07406    -1.2037209]
# нет комментарий
#  [-17.46517    -1.3535817]
# нет комментарий
#  [-17.17807    -1.7463104]
# нет комментарий
#  [-17.291739   -2.3936164]
# нет комментарий
#  [-16.516533   -1.9377989]
# нет комментарий
#  [-17.19235     -0.88714045]
# нет комментарий
#  [-17.19023    -1.3744352]
# нет комментарий
#  [-17.293756   -1.5424482]
# нет комментарий
#  [-16.767841    -0.80062574]
# нет комментарий
#  [-17.153881   -1.4605602]
# нет комментарий
#  [-17.386143   -1.8221139]
# нет комментарий
#  [-16.237123   -1.6183255]
# нет комментарий
#  [-17.256752   -1.7472904]
# нет комментарий
#  [-17.118769   -1.2196286]
# нет комментарий
#  [-17.069221   -1.3941588]
# нет комментарий
#  [-17.290846   -1.8092084]
# нет комментарий
#  [-16.676512   -0.6758959]
# нет комментарий
#  [-17.887564   -1.1493347]
# нет комментарий
#  [-16.955963   -1.6138995]
# нет комментарий
#  [-17.182457   -1.7426497]
# нет комментарий
#  [-16.616865   -1.6263208]
# нет комментарий
#  [-17.901167   -1.7580919]
# нет комментарий
#  [-17.399078   -1.0335764]
# нет комментарий
#  [-17.235477    -0.49328625]
# нет комментарий
#  [-17.130177   -2.3179076]
# нет комментарий
#  [-17.718132   -1.1839114]
# нет комментарий
#  [-16.72495    -2.2955432]
# нет комментарий
#  [-17.400864    -0.85247976]
# нет комментарий
#  [-17.417917    -0.83570975]
# нет комментарий
#  [-17.38603    -0.9363041]
# нет комментарий
#  [-17.034271   -2.1019788]
# нет комментарий
#  [-17.809614   -1.5374215]
# нет комментарий
#  [-16.918749    -0.83004993]
# нет комментарий
#  [-17.921434  -1.152508]
# нет комментарий
#  [-17.257032   -2.0743494]
# нет комментарий
#  [-17.130678   -2.3856053]
# нет комментарий
#  [-16.714651   -1.0193238]
# нет комментарий
#  [-17.09668    -1.7682587]
# нет комментарий
#  [-17.240831   -1.3146772]
# нет комментарий
#  [-17.428385   -1.0777564]
# нет комментарий
#  [-16.54202    -1.3053359]
# нет комментарий
#  [-17.896917  -1.870618]
# нет комментарий
#  [-17.107481  -2.38484 ]
# нет комментарий
#  [-17.898832    -0.89504623]
# нет комментарий
#  [-17.24002   -1.291651]
# нет комментарий
#  [-17.183582   -0.5287556]
# нет комментарий
#  [-17.69843    -0.8509814]
# нет комментарий
#  [-17.7968     -1.5067905]
# нет комментарий
#  [-17.04911    -1.0851796]
# нет комментарий
#  [-16.621365   -1.6692189]
# нет комментарий
#  [-17.573545   -1.3899922]
# нет комментарий
#  [-16.86285    -1.1290429]
# нет комментарий
#  [-17.154184   -1.3943788]
# нет комментарий
#  [-16.711088  -0.635986]
# нет комментарий
#  [-17.801472   -1.4040627]
# нет комментарий
#  [-17.82968  -1.39077]
# нет комментарий
#  [-16.67922    -1.3239324]
# нет комментарий
#  [-17.180454   -1.9204835]
# нет комментарий
#  [-16.95812    -1.9831941]
# нет комментарий
#  [-16.439016   -1.2635462]
# нет комментарий
#  [-17.739452   -2.1681848]
# нет комментарий
#  [-17.86222   -1.759516]
# нет комментарий
#  [-16.449984   -1.6971016]
# нет комментарий
#  [-17.275013   -1.0148729]
# нет комментарий
#  [-16.474215   -2.0032458]
# нет комментарий
#  [-16.981781   -1.5997124]
# нет комментарий
#  [-17.28632  -2.01214]
# нет комментарий
#  [-16.827854   -1.5541598]
# нет комментарий
#  [-17.590492   -1.8759843]
# нет комментарий
#  [-17.312876   -2.4107122]
# нет комментарий
#  [-16.663338   -1.5244607]
# нет комментарий
#  [-17.309462  -2.03415 ]
# нет комментарий
#  [-17.234512    -0.53626156]
# нет комментарий
#  [-16.961456   -1.4526381]
# нет комментарий
#  [-16.937698    -0.88241684]
# нет комментарий
#  [-17.536112   -2.1673026]
# нет комментарий
#  [-16.485626  -1.982033]
# нет комментарий
#  [-17.635218   -1.0941026]
# нет комментарий
#  [-17.356825   -1.6919298]
# нет комментарий
#  [-17.599512   -2.1406677]
# нет комментарий
#  [-17.42757    -1.0230664]
# нет комментарий
#  [-17.68667    -1.2000105]
# нет комментарий
#  [-17.650255   -1.5025983]
# нет комментарий
#  [-17.291159   -1.4825022]
# нет комментарий
#  [-17.311726   -2.4056008]
# нет комментарий
#  [-16.641867   -1.5023164]
# нет комментарий
#  [-17.13083     -0.90268856]
# нет комментарий
#  [-17.62789   -1.093724]
# нет комментарий
#  [-17.49943    -1.8793296]
# нет комментарий
#  [-16.702168   -1.3568875]
# нет комментарий
#  [-17.113306    -0.73875695]
# нет комментарий
#  [-17.840496   -1.4079868]
# нет комментарий
#  [-17.242773   -1.4987196]
# нет комментарий
#  [-17.29212    -1.5362549]
# нет комментарий
#  [-16.833147  -1.57025 ]
# нет комментарий
#  [-16.505636  -1.082674]
# нет комментарий
#  [-16.977144   -1.5966291]
# нет комментарий
#  [-17.225212   -1.5230696]
# нет комментарий
#  [-16.664677   -1.6202543]
# нет комментарий
#  [-17.296148   -1.7663091]
# нет комментарий
#  [-16.435453   -1.3409573]
# нет комментарий
#  [-17.68511    -0.8329991]
# нет комментарий
#  [-17.711098   -2.1227438]
# нет комментарий
#  [-17.099577   -1.7144265]
# нет комментарий
#  [-16.45679    -1.6653069]
# нет комментарий
#  [-17.259691   -1.6520697]
# нет комментарий
#  [-17.576162   -2.2040064]
# нет комментарий
#  [-16.912811  -2.032781]
# нет комментарий
#  [-17.479292   -1.3232162]
# нет комментарий
#  [-17.838951   -1.3794693]
# нет комментарий
#  [-17.175123   -1.0053135]
# нет комментарий
#  [-17.035069   -1.4017367]
# нет комментарий
#  [-16.237263   -1.6177614]
# нет комментарий
#  [-17.001726   -1.4096202]
# нет комментарий
#  [-16.740517    -0.82785314]
# нет комментарий
#  [-17.889378   -0.9349957]
# нет комментарий
#  [-17.90484    -1.7116005]
# нет комментарий
#  [-17.79733    -1.7600969]
# нет комментарий
#  [-17.704517   -1.2386322]
# нет комментарий
#  [-16.769655  -0.99049 ]
# нет комментарий
#  [-17.963198   -1.9015108]
# нет комментарий
#  [-17.943491  -1.908503]
# нет комментарий
#  [-16.64989   -1.872407]
# нет комментарий
#  [-17.665249   -1.0359063]
# нет комментарий
#  [-16.462975   -1.6488619]
# нет комментарий
#  [-16.920738   -1.9750934]
# нет комментарий
#  [-16.605516   -1.5251347]
# нет комментарий
#  [-16.734505   -0.9595363]
# нет комментарий
#  [-17.480566   -1.4688267]
# нет комментарий
#  [-17.836594  -1.284755]
# нет комментарий
#  [-16.77795    -0.8380097]
# нет комментарий
#  [-17.364868   -1.0815006]
# нет комментарий
#  [-17.250088  -2.00422 ]
# нет комментарий
#  [-17.502953  -0.664989]
# нет комментарий
#  [-17.298841  -1.09653 ]
# нет комментарий
#  [-17.270016   -0.5132747]
# нет комментарий
#  [-17.172016  -0.892295]
# нет комментарий
#  [-17.267326    -0.57185715]
# нет комментарий
#  [-17.66154    -1.2550801]
# нет комментарий
#  [-17.479567  -0.673847]
# нет комментарий
#  [-16.961172   -1.8278662]
# нет комментарий
#  [-16.980942   -1.2254231]
# нет комментарий
#  [-16.715847   -1.0104675]
# нет комментарий
#  [-17.274574   -1.3045163]
# нет комментарий
#  [-16.603016   -1.5771854]
# нет комментарий
#  [-17.61106    -1.7786509]
# нет комментарий
#  [-16.675724   -1.3294284]
# нет комментарий
#  [-16.95217    -1.2251395]
# нет комментарий
#  [-17.472183   -0.6854771]
# нет комментарий
#  [-17.337502   -1.5918294]
# нет комментарий
#  [-17.255041    -0.93511784]
# нет комментарий
#  [-17.193062   -1.2525123]
# нет комментарий
#  [-17.360155  -2.399577]
# нет комментарий
#  [-16.754318    -0.78598744]
# нет комментарий
#  [-17.549974   -1.1892648]
# нет комментарий
#  [-16.628784   -1.8945943]
# нет комментарий
#  [-17.20759    -1.1714667]
# нет комментарий
#  [-17.263914   -1.6828971]
# нет комментарий
#  [-17.1756     -1.7126822]
# нет комментарий
#  [-17.247974   -1.7487509]
# нет комментарий
#  [-17.302692   -1.8207963]
# нет комментарий
#  [-16.91908    -1.6551626]
# нет комментарий
#  [-17.20288    -0.9601715]
# нет комментарий
#  [-17.2234     -1.1612566]
# нет комментарий
#  [-16.849302   -1.5764033]
# нет комментарий
#  [-17.301336   -2.0051804]
# нет комментарий
#  [-16.57083    -1.6634593]
# нет комментарий
#  [-17.482107   -0.6770484]
# нет комментарий
#  [-17.291834   -2.3919337]
# нет комментарий
#  [-16.70026    -1.4351256]
# нет комментарий
#  [-17.061968   -1.3875835]
# нет комментарий
#  [-17.099133   -0.7330512]
# нет комментарий
#  [-16.613909   -1.5040815]
# нет комментарий
#  [-17.365818  -0.797205]
# нет комментарий
#  [-17.64338     -0.84831953]
# нет комментарий
#  [-16.756979    -0.96586686]
# нет комментарий
#  [-16.712313   -2.2477036]
# нет комментарий
#  [-17.658829   -1.7302818]
# нет комментарий
#  [-16.979837   -1.7108756]
# нет комментарий
#  [-17.417622   -1.1055995]
# нет комментарий
#  [-16.80116     -0.85142565]
# нет комментарий
#  [-16.823572   -0.9932692]
# нет комментарий
#  [-17.905905   -1.8909848]
# нет комментарий
#  [-17.108898   -1.7542369]
# нет комментарий
#  [-17.480118   -1.8476943]
# нет комментарий
#  [-17.894257   -1.1642606]
# нет комментарий
#  [-16.698202  -1.896256]
# нет комментарий
#  [-17.83124    -1.7114384]
# нет комментарий
#  [-17.20769    -0.8720969]
# нет комментарий
#  [-17.574034   -1.4735516]
# нет комментарий
#  [-17.566048   -1.5076315]
# нет комментарий
#  [-17.039976   -1.3574134]
# нет комментарий
#  [-16.984735  -2.088117]
# нет комментарий
#  [-17.668123   -0.8007432]
# нет комментарий
#  [-17.086514   -1.4625958]
# нет комментарий
#  [-17.122984   -2.2059622]
# нет комментарий
#  [-17.065447   -0.7353961]
# нет комментарий
#  [-17.019215   -1.2274172]
# нет комментарий
#  [-16.662697   -1.9456811]
# нет комментарий
#  [-16.636122   -1.4061439]
# нет комментарий
#  [-17.46106    -1.5277581]
# нет комментарий
#  [-16.54823    -1.4058418]
# нет комментарий
#  [-17.049976   -1.3398987]
# нет комментарий
#  [-17.557123  -1.606172]
# нет комментарий
#  [-16.925692   -2.0388896]
# нет комментарий
#  [-17.68398     -0.86546165]
# нет комментарий
#  [-16.740072   -2.2926362]
# нет комментарий
#  [-16.919209   -1.6453435]
# нет комментарий
#  [-17.11963    -1.2387209]
# нет комментарий
#  [-16.746887   -2.2923362]
# нет комментарий
#  [-17.168432   -0.8898279]
# нет комментарий
#  [-17.815617   -1.3555802]
# нет комментарий
#  [-16.585087   -1.6153175]
# нет комментарий
#  [-16.908417   -0.8399462]
# нет комментарий
#  [-17.009289   -1.4486343]
# нет комментарий
#  [-16.66623    -1.9744457]
# нет комментарий
#  [-17.220165   -1.4827969]
# нет комментарий
#  [-16.50018    -1.3499635]
# нет комментарий
#  [-17.462969   -1.9277282]
# нет комментарий
#  [-17.101877   -1.8868521]
# нет комментарий
#  [-17.222275   -1.0440941]
# нет комментарий
#  [-16.677086   -0.6306535]
# нет комментарий
#  [-17.654037  -2.099193]
# нет комментарий
#  [-17.555153  -1.925272]
# нет комментарий
#  [-17.499578   -1.7412877]
# нет комментарий
#  [-17.972559   -1.8990775]
# нет комментарий
#  [-16.233896   -1.5917343]
# нет комментарий
#  [-16.809437    -0.90295327]
# нет комментарий
#  [-16.751665   -1.4175184]
# нет комментарий
#  [-17.364262   -1.5754772]
# нет комментарий
#  [-17.41786    -1.8642294]
# нет комментарий
#  [-17.803204   -1.2655251]
# нет комментарий
#  [-17.2142      -0.54866636]
# нет комментарий
#  [-16.758831   -1.2736323]
# нет комментарий
#  [-16.77481    -2.2555518]
# нет комментарий
#  [-17.182882   -1.5141661]
# нет комментарий
#  [-16.958052   -1.6686405]
# нет комментарий
#  [-16.649893   -1.6190134]
# нет комментарий
#  [-17.246174  -1.791181]
# нет комментарий
#  [-17.084368   -2.3710632]
# нет комментарий
#  [-17.292423   -1.8123361]
# нет комментарий
#  [-17.89579     -0.89943177]
# нет комментарий
#  [-17.159214   -1.7153043]
# нет комментарий
#  [-16.650139   -1.9351194]
# нет комментарий
#  [-17.453308   -1.0044817]
# нет комментарий
#  [-17.723492   -2.1312118]
